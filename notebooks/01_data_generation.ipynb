# %% [markdown]
# # 01. Data Generation
# This notebook generates realistic synthetic e-commerce data.

# %%
# Code is provided in generate_data.py
# Run the script to generate data:
# !python ../generate_data.py
